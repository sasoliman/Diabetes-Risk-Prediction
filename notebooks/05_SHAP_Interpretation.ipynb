# %% [markdown]
# # Diabetes Risk Prediction
#
# # 10 - SHAP Model Interpretation
#
# ## Objectives
#
# This notebook provides a comprehensive interpretation of the trained CatBoost diabetes prediction model using SHAP (SHapley Additive exPlanations).
#
# The workflow includes:
#
# - Loading the trained CatBoost model
# - Reconstructing the training and testing datasets
# - Computing SHAP values
# - Global feature importance
# - Local feature interpretation
# - Dependence plots
# - Waterfall plots
# - Force plots
# - Decision plots
#
# ## Input
#
# data/processed/diabetes_processed.parquet
#
# models/catboost/catboost_model.cbm
#
# results/catboost/train_test_split.json
#
# ## Outputs
#
# figures/shap/catboost/
#
# results/shap/

# %%
# ===============================================================
# Import Libraries
# ===============================================================

from pathlib import Path
import json

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import shap

import scipy

from catboost import CatBoostClassifier
